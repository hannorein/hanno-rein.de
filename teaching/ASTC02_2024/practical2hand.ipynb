# %%
from imageio.v3 import imread
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.patches import Rectangle

# %%
image =  imread("/Users/rein/Documents/Teaching/2024-2025/ASTC02/eVscope-20220103-030044.PNG")

# %%
image = np.average(image,axis=2)

# %%
fig, ax = plt.subplots(1,1)
ax.imshow(image, interpolation="none")

# %%
fig, ax = plt.subplots(1,1)
ax.imshow(image > 20, interpolation="none")

# %%
dark =  imread("/Users/rein/Documents/Teaching/2024-2025/ASTC02/dark.PNG")
dark = np.average(dark,axis=2)

# %%
fig, ax = plt.subplots(1,1)
i = ax.imshow(dark, interpolation="none")
fig.colorbar(i)

# %%
corrected = image - dark

# %%
fig, ax = plt.subplots(1,2)
ax[0].imshow(image, interpolation="none")
ax[1].imshow(corrected, interpolation="none")

# %%
fig, ax = plt.subplots(1,1)
cropped = corrected[1000:1100,550:650]
ax.imshow(cropped, interpolation="none")

# %%
fig, ax = plt.subplots(1,1)
cropped = corrected[1010:1060,570:620]
ax.imshow(cropped, interpolation="none")

# %%
flux = np.sum(cropped)
flux
# Out:
# 59240.333333333336
